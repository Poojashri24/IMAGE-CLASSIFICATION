# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
data_train_path = 'Fruits_Vegetables/train'
data_test_path='Fruits_Vegetables/test'
data_val_path='Fruits_Vegetables/validation'

# %%
img_width=180
img_height=180

# %%
data_train=tf.keras.utils.image_dataset_from_directory(data_train_path,shuffle=True,image_size=(img_width,img_height),batch_size=32,validation_split=False)
# Out:
# Found 3115 files belonging to 36 classes.

# %%
data_cat=data_train.class_names

# %%
data_cat
# Out:
# ['apple',
#  'banana',
#  'beetroot',
#  'bell pepper',
#  'cabbage',
#  'capsicum',
#  'carrot',
#  'cauliflower',
#  'chilli pepper',
#  'corn',
#  'cucumber',
#  'eggplant',
#  'garlic',
#  'ginger',
#  'grapes',
#  'jalepeno',
#  'kiwi',
#  'lemon',
#  'lettuce',
#  'mango',
#  'onion',
#  'orange',
#  'paprika',
#  'pear',
#  'peas',
#  'pineapple',
#  'pomegranate',
#  'potato',
#  'raddish',
#  'soy beans',
#  'spinach',
#  'sweetcorn',
#  'sweetpotato',
#  'tomato',
#  'turnip',
#  'watermelon']

# %%
data_val=tf.keras.utils.image_dataset_from_directory(data_val_path,image_size=(img_height,img_width),batch_size=32,shuffle=False,validation_split=False)
# Out:
# Found 351 files belonging to 36 classes.

# %%
data_test=tf.keras.utils.image_dataset_from_directory(data_test_path,image_size=(img_height,img_width),batch_size=32,shuffle=False,validation_split=False)
# Out:
# Found 359 files belonging to 36 classes.

# %%
plt.figure(figsize=(10,10))
for image,labels in data_train.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(data_cat[labels[i]])
        plt.axis('off')

# %%
from tensorflow.keras.models import Sequential

# %%
model=Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16,3,padding='same',activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32,3,padding='same',activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64,3,padding='same',activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dropout(0.2),
    layers.Dense(128),
    layers.Dense(len(data_cat))])

# %%
model.compile(optimizer='adam',loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])

# %%
epochs_size=25 
history=model.fit(data_train,validation_data=data_val,epochs=epochs_size)
# Out:
# Epoch 1/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 81s 776ms/step - accuracy: 0.0427 - loss: 3.9590 - val_accuracy: 0.2422 - val_loss: 2.7241
# Epoch 2/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 558ms/step - accuracy: 0.2306 - loss: 2.7667 - val_accuracy: 0.5328 - val_loss: 1.8252
# Epoch 3/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 53s 536ms/step - accuracy: 0.4123 - loss: 2.1145 - val_accuracy: 0.7607 - val_loss: 0.8929
# Epoch 4/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 54s 551ms/step - accuracy: 0.5971 - loss: 1.4065 - val_accuracy: 0.8632 - val_loss: 0.5339
# Epoch 5/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 563ms/step - accuracy: 0.7692 - loss: 0.8141 - val_accuracy: 0.9031 - val_loss: 0.4696
# Epoch 6/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 54s 552ms/step - accuracy: 0.8593 - loss: 0.4971 - val_accuracy: 0.9288 - val_loss: 0.3709
# Epoch 7/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 57s 582ms/step - accuracy: 0.9100 - loss: 0.3151 - val_accuracy: 0.9231 - val_loss: 0.5252
# Epoch 8/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 64s 651ms/step - accuracy: 0.9223 - loss: 0.2801 - val_accuracy: 0.9516 - val_loss: 0.3218
# Epoch 9/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 62s 631ms/step - accuracy: 0.9533 - loss: 0.1911 - val_accuracy: 0.9459 - val_loss: 0.4114
# Epoch 10/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 63s 636ms/step - accuracy: 0.9598 - loss: 0.1635 - val_accuracy: 0.9516 - val_loss: 0.3737
# Epoch 11/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 63s 643ms/step - accuracy: 0.9683 - loss: 0.1275 - val_accuracy: 0.9544 - val_loss: 0.3667
# Epoch 12/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 60s 601ms/step - accuracy: 0.9748 - loss: 0.1231 - val_accuracy: 0.9573 - val_loss: 0.3586
# Epoch 13/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 53s 542ms/step - accuracy: 0.9836 - loss: 0.0966 - val_accuracy: 0.9573 - val_loss: 0.3537
# Epoch 14/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 54s 544ms/step - accuracy: 0.9777 - loss: 0.1093 - val_accuracy: 0.9487 - val_loss: 0.3576
# Epoch 15/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 54s 551ms/step - accuracy: 0.9724 - loss: 0.1151 - val_accuracy: 0.9516 - val_loss: 0.3041
# Epoch 16/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 54s 549ms/step - accuracy: 0.9699 - loss: 0.1238 - val_accuracy: 0.9573 - val_loss: 0.3820
# Epoch 17/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 54s 547ms/step - accuracy: 0.9801 - loss: 0.1135 - val_accuracy: 0.9573 - val_loss: 0.2821
# Epoch 18/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 54s 551ms/step - accuracy: 0.9712 - loss: 0.1262 - val_accuracy: 0.9630 - val_loss: 0.3869
# Epoch 19/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 53s 545ms/step - accuracy: 0.9824 - loss: 0.0823 - val_accuracy: 0.9516 - val_loss: 0.4106
# Epoch 20/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 54s 551ms/step - accuracy: 0.9802 - loss: 0.0770 - val_accuracy: 0.9487 - val_loss: 0.3939
# Epoch 21/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 53s 542ms/step - accuracy: 0.9800 - loss: 0.1045 - val_accuracy: 0.9516 - val_loss: 0.3349
# Epoch 22/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 54s 551ms/step - accuracy: 0.9785 - loss: 0.0930 - val_accuracy: 0.9487 - val_loss: 0.3520
# Epoch 23/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 54s 545ms/step - accuracy: 0.9751 - loss: 0.1004 - val_accuracy: 0.9544 - val_loss: 0.3010
# Epoch 24/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 57s 576ms/step - accuracy: 0.9851 - loss: 0.0682 - val_accuracy: 0.9544 - val_loss: 0.3173
# Epoch 25/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 54s 548ms/step - accuracy: 0.9837 - loss: 0.0533 - val_accuracy: 0.9544 - val_loss: 0.3283

# %%
epochs_range=range(epochs_size)
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_range,history.history['accuracy'],label='Training Accuracy')
plt.plot(epochs_range,history.history['val_accuracy'],label='Validation Accuracy')
plt.title('Accuracy')
plt.subplot(1,2,2)
plt.plot(epochs_range,history.history['loss'],label='Training Loss')
plt.plot(epochs_range,history.history['val_loss'],label='Validation Loss')
plt.title('Accuracy')
# Out:
# Text(0.5, 1.0, 'Accuracy')

# %%
image='Carrot.jpeg'
image=tf.keras.utils.load_img(image,target_size=(img_height,img_width))
img_arr=tf.keras.utils.array_to_img(image)
img_bat=tf.expand_dims(img_arr,0)

# %%
predict=model.predict(img_bat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step

# %%
score=tf.nn.softmax(predict)

# %%
print('Veg/Fruit in image is {} with accuracy of {:0.2f}'.format(data_cat[np.argmax(score)],np.max(score)*100))
# Out:
# Veg/Fruit in image is carrot with accuracy of 99.99

# %%
model.save('Image_classify.keras')
